# %% [markdown]
# ## Stress Patterns in Intra-word Code-switching
# ### Data: joining meta&annotated df
#
# #### Source: Praat Annotation, Excel sheet
# ##### Annotated files #: 4 audio files (inflected forms) & 4 additional audio files (uninflected forms)
# ##### Date: 5/8/2025

# %% [markdown]
# ### Stress Dataset

# %%
import csv
import pandas as pd
import os
import numpy as np

# %%
# Load metadata

# Read all sheets into a dictionary
file_path = "/Users/aidyn/Documents/Fall_2024_IndStudy/CompletedAnnotations/StimuliListUpdated.xlsx"
sheets_dict = pd.read_excel(file_path, sheet_name=None)

# Access each sheet by its name
for sheet_name, sheet_data in sheets_dict.items():
    print(f"Sheet Name: {sheet_name}")
    print(sheet_data.head())
# Out:
# Sheet Name: RussianNounCS
#         Word  StressedSyll NounGender  Declension StressShift ShiftDirect  \
# 0   правдаға             1          f           1          no          na
# 1  группалар             1          f           1          no          na
# 2   пользаны             1          f           1          no          na
# 3   книгалар             1          f           1          no          na
# 4     силаны             1          f           1          no          na
#
#   AttestedInCS
# 0          yes
# 1          yes
# 2          yes
# 3          yes
# 4          yes
# Sheet Name: WordList
#   SyllStrWord      Word Language SuffixCase SyllStrCase  ForLater  Stress  \
# 0   CVC-CV-CV   жылқыға      Kaz        DAT          CV       NaN     NaN
# 1  CVC-CV-CVC  шалғылар      Kaz     PLURAL         CVC       NaN     NaN
# 2   CVC-CV-CV   пайданы      Kaz        ACC          CV       NaN     NaN
# 3   CV-CV-CVC   шекелер      Kaz     PLURAL         CVC       NaN     NaN
# 4    CV-CV-CV    қаланы      Kaz        ACC          CV       NaN     NaN
#
#     WordForm LatinScript        Gloss WordClass
# 0  inflected     jylqyǵa    horse.DAT      Noun
# 1  inflected   shalǵylar    scythe.Pl      Noun
# 2  inflected     paidany  benefit.ACC      Noun
# 3  inflected    shekeler  forehead.Pl      Noun
# 4  inflected      qalany      city.Pl      Noun
# Sheet Name: VowelQualityKaz
#   CASE     SuffixLatin SuffixCyrillic SyllStrCase VowelCyrillic VowelIPA  \
# 0   ACC     ny, dy, ty     ны, ды, ты          CV             ы        ə
# 1   ACC     ni, di, ti     ні, ді, ті          CV             і        ɪ
# 2   DAT         ga, qa         ға, қа          CV             а        ɑ
# 3   DAT       gie, kie          ге,ке          CV             е       ie
# 4   GEN  nyn, dyn, tyn  ның, дың, тың         CVC             ы        ə
#
#   VowelHeight VowelBackness Language
# 0         mid          back      Kaz
# 1        high         front      Kaz
# 2         low          back      Kaz
# 3        high         front      Kaz
# 4         mid          back      Kaz
# Sheet Name: VowelQualityRus
#   VowelCyrillic VowelIPA VowelHeight VowelBackness Language
# 0             ы        ə         mid       central      Rus
# 1             і        i        high         front      Rus
# 2             а        a         low       central      Rus
# 3             е        e         mid         front      Rus
# 4             o       o          mid          back      Rus
# Sheet Name: AdditionRN
#   RussianNoun (Cyrillic) Latin Script                               Notes
# 0                 прАвда       prAvda  a popular jounal name, test token?
# 1                 грУппа       grUppa                    test trial token
# 2                 пОльза       pOl'za                                 NaN
# 3                  кнИга        knIga                                 NaN
# 4                   сИла         sIla                                 NaN

# %%
pwd
# Out:
# '/Users/aidyn/Documents/Fall_2024_IndStudy/CompletedAnnotations'

# %%
# Save dict into CSV files
output_directory = "/Users/aidyn/Documents/Fall_2024_IndStudy/CompletedAnnotations/metadata_csv"  

# Iterate over the dictionary and save each sheet as a CSV file
for sheet_name, sheet_data in sheets_dict.items():
    # Construct the output file path
    output_file = f"{sheet_name}.csv"
    
    # Save the DataFrame as a CSV file
    sheet_data.to_csv(output_file, index=False)
    print(f"Saved {sheet_name} to {output_file}")
# Out:
# Saved RussianNounCS to RussianNounCS.csv
# Saved WordList to WordList.csv
# Saved VowelQualityKaz to VowelQualityKaz.csv
# Saved VowelQualityRus to VowelQualityRus.csv
# Saved AdditionRN to AdditionRN.csv

# %%
# Read csv files

stimulus_cs = pd.read_csv("/Users/aidyn/Documents/Fall_2024_IndStudy/CompletedAnnotations/metadata_csv/RussianNounCS.csv")
stimulus_kaz_rus = pd.read_csv("/Users/aidyn/Documents/Fall_2024_IndStudy/CompletedAnnotations/metadata_csv/WordList.csv")
vowel_quality_kaz = pd.read_csv("/Users/aidyn/Documents/Fall_2024_IndStudy/CompletedAnnotations/metadata_csv/VowelQualityKaz.csv")
vowel_quality_rus = pd.read_csv("/Users/aidyn/Documents/Fall_2024_IndStudy/CompletedAnnotations/metadata_csv/VowelQualityRus.csv")

# %%
stimulus_cs
# Out:
#           Word  StressedSyll NounGender  Declension StressShift ShiftDirect  \
# 0     правдаға             1          f           1          no          na
# 1    группалар             1          f           1          no          na
# 2     пользаны             1          f           1          no          na
# 3     книгалар             1          f           1          no          na
# 4       силаны             1          f           1          no          na
# ..         ...           ...        ...         ...         ...         ...
# 115       окнa             2          n           2         yes    backward
# 116       селa             2          n           2         yes    backward
# 117      земли             1          f           2         yes    backward
# 118       души             1          f           2         yes    backward
# 119       реки             1          f           2         yes    backward
#
#     AttestedInCS
# 0            yes
# 1            yes
# 2            yes
# 3            yes
# 4            yes
# ..           ...
# 115           no
# 116          yes
# 117           no
# 118          yes
# 119          yes
#
# [120 rows x 7 columns]

# %%
stimulus_kaz_rus
# Out:
#     SyllStrWord      Word Language SuffixCase SyllStrCase  ForLater  Stress  \
# 0     CVC-CV-CV   жылқыға      Kaz        DAT          CV       NaN     NaN
# 1    CVC-CV-CVC  шалғылар      Kaz     PLURAL         CVC       NaN     NaN
# 2     CVC-CV-CV   пайданы      Kaz        ACC          CV       NaN     NaN
# 3     CV-CV-CVC   шекелер      Kaz     PLURAL         CVC       NaN     NaN
# 4      CV-CV-CV    қаланы      Kaz        ACC          CV       NaN     NaN
# ..          ...       ...      ...        ...         ...       ...     ...
# 195         NaN      олжа      Kaz        NaN         NaN       NaN     NaN
# 196         NaN      сәби      Kaz        NaN         NaN       NaN     NaN
# 197         NaN     жеңге      Kaz        NaN         NaN       NaN     NaN
# 198         NaN      төбе      Kaz        NaN         NaN       NaN     NaN
# 199         NaN      шеге      Kaz        NaN         NaN       NaN     NaN
#
#         WordForm LatinScript            Gloss WordClass
# 0      inflected     jylqyǵa        horse.DAT      Noun
# 1      inflected   shalǵylar        scythe.Pl      Noun
# 2      inflected     paidany      benefit.ACC      Noun
# 3      inflected    shekeler      forehead.Pl      Noun
# 4      inflected      qalany          city.Pl      Noun
# ..           ...         ...              ...       ...
# 195  uninflected        olja           trophy      Noun
# 196  uninflected        sábi            child      Noun
# 197  uninflected       jeńge  daughter-in-law      Noun
# 198  uninflected        tóbe             hill      Noun
# 199  uninflected       shege             nail      Noun
#
# [200 rows x 11 columns]

# %%
stimulus_kaz_rus = stimulus_kaz_rus[["Word", "Language", "SuffixCase", "WordForm","LatinScript", "Gloss","WordClass"]]

# %%
stimulus_kaz_rus
# Out:
#          Word Language SuffixCase     WordForm LatinScript            Gloss  \
# 0     жылқыға      Kaz        DAT    inflected     jylqyǵa        horse.DAT
# 1    шалғылар      Kaz     PLURAL    inflected   shalǵylar        scythe.Pl
# 2     пайданы      Kaz        ACC    inflected     paidany      benefit.ACC
# 3     шекелер      Kaz     PLURAL    inflected    shekeler      forehead.Pl
# 4      қаланы      Kaz        ACC    inflected      qalany          city.Pl
# ..        ...      ...        ...          ...         ...              ...
# 195      олжа      Kaz        NaN  uninflected        olja           trophy
# 196      сәби      Kaz        NaN  uninflected        sábi            child
# 197     жеңге      Kaz        NaN  uninflected       jeńge  daughter-in-law
# 198      төбе      Kaz        NaN  uninflected        tóbe             hill
# 199      шеге      Kaz        NaN  uninflected       shege             nail
#
#     WordClass
# 0        Noun
# 1        Noun
# 2        Noun
# 3        Noun
# 4        Noun
# ..        ...
# 195      Noun
# 196      Noun
# 197      Noun
# 198      Noun
# 199      Noun
#
# [200 rows x 7 columns]

# %%
vowel_quality_kaz = vowel_quality_kaz[["VowelCyrillic", "VowelIPA", "VowelHeight", "VowelBackness", "Language"]]
vowel_quality_kaz
# Out:
#    VowelCyrillic VowelIPA VowelHeight VowelBackness Language
# 0              ы        ə         mid          back      Kaz
# 1              і        ɪ        high         front      Kaz
# 2              а        ɑ         low          back      Kaz
# 3              е       ie        high         front      Kaz
# 4              ы        ə         mid          back      Kaz
# 5              і        ɪ        high         front      Kaz
# 6              а        ɑ         low          back      Kaz
# 7              е       ie        high         front      Kaz
# 8              и      ij        high          front      Kaz
# 9              o       o          mid          back      Kaz
# 10             ұ       ʊ         high          back      Kaz
# 11             у      uw         high          back      Kaz
# 12             ә       æ          low         front      Kaz
# 13             ө       ɵ         high        front       Kaz
# 14             ү        ʏ       high         front       Kaz

# %%
vowel_quality_rus
# Out:
#   VowelCyrillic VowelIPA VowelHeight VowelBackness Language
# 0             ы        ə         mid       central      Rus
# 1             і        i        high         front      Rus
# 2             а        a         low       central      Rus
# 3             е        e         mid         front      Rus
# 4             o       o          mid          back      Rus
# 5             у       ʊ         high          back      Rus
# 6             ы        ɨ        high         front      Rus
# 7             у        u        high          back      Rus
# 8             e       ɛ          mid         front      Rus
# 9           o,a        ʌ         mid          back      Rus

# %%
# Load annotated data - for 1 speaker only
# Read all sheets into a dictionary
file_path_sd = "/Users/aidyn/Documents/Fall_2024_IndStudy/DataProcessing/speaker1Measurements_updated.xlsx"
sheets_dict = pd.read_excel(file_path_sd, sheet_name=None)

# Iterate over the dictionary and save each sheet as a CSV file
for sheet_name, sheet_data in sheets_dict.items():
    # Construct the output file path
    output_file = f"{sheet_name}.csv"
    
    # Save the DataFrame as a CSV file
    sheet_data.to_csv(output_file, index=False)
    print(f"Saved {sheet_name} to {output_file}")
# Out:
# Saved speaker1Measurements copy to speaker1Measurements copy.csv

# %%
pwd
# Out:
# '/Users/aidyn/Documents/Fall_2024_IndStudy/CompletedAnnotations'

# %%
# Excel workbooks
excel_files = ['male_main.xlsx', 'male_add.xlsx', 'female_main.xlsx', 'female_add.xlsx']

# Read Excel files into DataFrame
dataframes = [pd.read_excel(file) for file in excel_files]

# Combine all DataFrames into one 
combined_df = pd.concat(dataframes, ignore_index=True)

# Print first few rows of the DataFrame
print(combined_df.head())

# Save the combined DataFrame to a CSV file
combined_df.to_csv('combined_data.csv', index=False)
# Out:
#          Filename     Word  WordInterval Syllable             SylInterval  \
# 0  Speaker_1_male   вечерa             2  'syll$'  'parallelsyllinterval'
# 1  Speaker_1_male   вечерa             2  'syll$'  'parallelsyllinterval'
# 2  Speaker_1_male   вечерa             2  'syll$'  'parallelsyllinterval'
# 3  Speaker_1_male  олжаның             4  'syll$'  'parallelsyllinterval'
# 4  Speaker_1_male  олжаның             4  'syll$'  'parallelsyllinterval'
#
#    SegIntervalNr                 Vowel     Begin       End  Duration_in_ms  \
# 0              2             s1_cv_vʲɛ  1.889375  2.044858      155.482845
# 1              3  s2_cv_ʧʲɪ_unstressed  2.044858  2.238501      193.642926
# 2              4     s3_cv_ra_stressed  2.238501  2.499526      261.024641
# 3              6              s1_vc_ol  8.478645  8.669182      190.536827
# 4              7              s2_cv_ʒɑ  8.669182  8.915570      246.388278
#
#    ...          F0AtPoint1          F0AtPoint2          F0AtPoint3  \
# 0  ...  109.63265204141156  104.35065626539527  102.49127821549959
# 1  ...   108.1947021660767       --undefined--       --undefined--
# 2  ...  115.52645918680702  117.86416387695218  121.29690852810644
# 3  ...       --undefined--   123.7284450331763  120.85441035690577
# 4  ...  118.48326706520108  117.09417019379566  116.48717933813998
#
#            F0AtPoint4          F0AtPoint5          F0AtPoint6  \
# 0  105.52702923754437  110.79783808095402  116.12595990115243
# 1       --undefined--       --undefined--       --undefined--
# 2  123.80898203049698   129.1979305385731  136.61081017697276
# 3  118.32445192588568  114.26760413960666  111.71603508552155
# 4   114.5024660615793   112.7206940243868  116.28266974225471
#
#            F0AtPoint7          F0AtPoint8          F0AtPoint9  \
# 0  117.94314337335328  116.39063899071706  112.27079598361979
# 1       --undefined--  124.37495874393628  117.86532184168861
# 2  146.63234866977515  154.93604548571605   157.7039796119457
# 3   113.7282582549003  117.92197121471601  118.34365327483549
# 4  118.16324849591815   115.9261553215855  114.39753759926442
#
#           F0AtPoint10
# 0   108.1947021660767
# 1  115.52645918680702
# 2   141.9820290517729
# 3  118.48326706520108
# 4  112.67862903968746
#
# [5 rows x 50 columns]

# %%
combined_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1976 entries, 0 to 1975
# Data columns (total 50 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Filename         1976 non-null   object
#  1   Word             1975 non-null   object
#  2   WordInterval     1976 non-null   int64
#  3   Syllable         1976 non-null   object
#  4   SylInterval      1976 non-null   object
#  5   SegIntervalNr    1976 non-null   int64
#  6   Vowel            1976 non-null   object
#  7   Begin            1976 non-null   float64
#  8   End              1976 non-null   float64
#  9   Duration_in_ms   1976 non-null   float64
#  10  Max_dB           1976 non-null   float64
#  11  Min_dB           1976 non-null   float64
#  12  TimeMax_dB       1976 non-null   float64
#  13  TimeMin_dB       1976 non-null   float64
#  14  Mean_dB          1976 non-null   float64
#  15  Centre_mean_dB   1976 non-null   float64
#  16  Centre_max_dB    1976 non-null   float64
#  17  Centre_min_dB    1976 non-null   float64
#  18  Word_beg         1976 non-null   float64
#  19  Word_end         1976 non-null   float64
#  20  Word_dur_ms      1976 non-null   float64
#  21  Syl_beg          1976 non-null   object
#  22  Syl_end          1976 non-null   object
#  23  Syl_dur_ms       1976 non-null   object
#  24  MaxF0Hz          1976 non-null   object
#  25  TimeF0Max        1976 non-null   object
#  26  MinF0Hz          1976 non-null   object
#  27  TimeF0Min        1976 non-null   object
#  28  MeanF0           1976 non-null   object
#  29  Centre_MeanF0    1976 non-null   object
#  30  TimeF0AtPoint1   1976 non-null   float64
#  31  TimeF0AtPoint2   1976 non-null   float64
#  32  TimeF0AtPoint3   1976 non-null   float64
#  33  TimeF0AtPoint4   1976 non-null   float64
#  34  TimeF0AtPoint5   1976 non-null   float64
#  35  TimeF0AtPoint6   1976 non-null   float64
#  36  TimeF0AtPoint7   1976 non-null   float64
#  37  TimeF0AtPoint8   1976 non-null   float64
#  38  TimeF0AtPoint9   1976 non-null   float64
#  39  TimeF0AtPoint10  1976 non-null   float64
#  40  F0AtPoint1       1976 non-null   object
#  41  F0AtPoint2       1976 non-null   object
#  42  F0AtPoint3       1976 non-null   object
#  43  F0AtPoint4       1976 non-null   object
#  44  F0AtPoint5       1976 non-null   object
#  45  F0AtPoint6       1976 non-null   object
#  46  F0AtPoint7       1976 non-null   object
#  47  F0AtPoint8       1976 non-null   object
#  48  F0AtPoint9       1976 non-null   object
#  49  F0AtPoint10      1976 non-null   object
# dtypes: float64(24), int64(2), object(24)
# memory usage: 772.0+ KB

# %%
full_sample_data = pd.read_csv("/Users/aidyn/Documents/Fall_2024_IndStudy/CompletedAnnotations/combined_data.csv")
# pd.set_option('display.max_columns', None)
# pd.set_option('display.max_rows', None)
full_sample_data[:10]
# Out:
#          Filename     Word  WordInterval Syllable             SylInterval  \
# 0  Speaker_1_male   вечерa             2  'syll$'  'parallelsyllinterval'
# 1  Speaker_1_male   вечерa             2  'syll$'  'parallelsyllinterval'
# 2  Speaker_1_male   вечерa             2  'syll$'  'parallelsyllinterval'
# 3  Speaker_1_male  олжаның             4  'syll$'  'parallelsyllinterval'
# 4  Speaker_1_male  олжаның             4  'syll$'  'parallelsyllinterval'
# 5  Speaker_1_male  олжаның             4  'syll$'  'parallelsyllinterval'
# 6  Speaker_1_male  шекелер             6  'syll$'  'parallelsyllinterval'
# 7  Speaker_1_male  шекелер             6  'syll$'  'parallelsyllinterval'
# 8  Speaker_1_male  шекелер             6  'syll$'  'parallelsyllinterval'
# 9  Speaker_1_male  сөрелер             8  'syll$'  'parallelsyllinterval'
#
#    SegIntervalNr                 Vowel      Begin        End  Duration_in_ms  \
# 0              2             s1_cv_vʲɛ   1.889375   2.044858      155.482845
# 1              3  s2_cv_ʧʲɪ_unstressed   2.044858   2.238501      193.642926
# 2              4     s3_cv_ra_stressed   2.238501   2.499526      261.024641
# 3              6              s1_vc_ol   8.478645   8.669182      190.536827
# 4              7              s2_cv_ʒɑ   8.669182   8.915570      246.388278
# 5              8            s3_cvc_nəŋ   8.915570   9.155325      239.754521
# 6             10             s1_cv_ʃie  13.508227  13.757677      249.449606
# 7             11             s2_cv_kie  13.757677  13.923753      166.076394
# 8             12           s3_cvc_lier  13.923753  14.150535      226.781868
# 9             14              s1_cv_sɵ  18.792268  19.070072      277.803623
#
#    ...          F0AtPoint1          F0AtPoint2          F0AtPoint3  \
# 0  ...  109.63265204141156  104.35065626539527  102.49127821549959
# 1  ...   108.1947021660767       --undefined--       --undefined--
# 2  ...  115.52645918680702  117.86416387695218  121.29690852810644
# 3  ...       --undefined--   123.7284450331763  120.85441035690577
# 4  ...  118.48326706520108  117.09417019379566  116.48717933813998
# 5  ...  112.67862903968746  112.74893274269924   115.2186955991557
# 6  ...       --undefined--       --undefined--       --undefined--
# 7  ...  128.15429854249075       --undefined--       --undefined--
# 8  ...  121.69093662830693   111.0768725844573   106.0353728054569
# 9  ...       --undefined--       --undefined--       --undefined--
#
#            F0AtPoint4          F0AtPoint5          F0AtPoint6  \
# 0  105.52702923754437  110.79783808095402  116.12595990115243
# 1       --undefined--       --undefined--       --undefined--
# 2  123.80898203049698   129.1979305385731  136.61081017697276
# 3  118.32445192588568  114.26760413960666  111.71603508552155
# 4   114.5024660615793   112.7206940243868  116.28266974225471
# 5  120.85881910377083    130.530433173532  136.78238021681457
# 6       --undefined--       --undefined--       --undefined--
# 7       --undefined--       --undefined--       --undefined--
# 8  108.62285836418842   107.7774144593974   107.9682284398636
# 9       --undefined--       --undefined--       --undefined--
#
#            F0AtPoint7          F0AtPoint8          F0AtPoint9  \
# 0  117.94314337335328  116.39063899071706  112.27079598361979
# 1       --undefined--  124.37495874393628  117.86532184168861
# 2  146.63234866977515  154.93604548571605   157.7039796119457
# 3   113.7282582549003  117.92197121471601  118.34365327483549
# 4  118.16324849591815   115.9261553215855  114.39753759926442
# 5  148.16670467285218  151.58312972284287  146.22474970564122
# 6       --undefined--   133.9575451597551  131.96014028329182
# 7       --undefined--  134.01029549934054   129.4883327428241
# 8   108.8041558323174  108.32436854623923       --undefined--
# 9  133.58886245359832  132.24675122338584  133.48262100827304
#
#           F0AtPoint10
# 0   108.1947021660767
# 1  115.52645918680702
# 2   141.9820290517729
# 3  118.48326706520108
# 4  112.67862903968746
# 5   136.3487737467197
# 6  128.15429854249075
# 7  121.69093662830693
# 8       --undefined--
# 9  132.12643755792863
#
# [10 rows x 50 columns]

# %%
full_sample_data['Word'].isna().sum()
# Out:
# 0

# %%
full_sample_data[full_sample_data['Word'].isna()]
#full_sample_data[full_sample_data['Vowel'].isna()]
# Out:
# Empty DataFrame
# Columns: [Filename, Word, WordInterval, Syllable, SylInterval, SegIntervalNr, Vowel, Begin, End, Duration_in_ms, Max_dB, Min_dB, TimeMax_dB, TimeMin_dB, Mean_dB, Centre_mean_dB, Centre_max_dB, Centre_min_dB, Word_beg, Word_end, Word_dur_ms, Syl_beg, Syl_end, Syl_dur_ms, MaxF0Hz, TimeF0Max, MinF0Hz, TimeF0Min, MeanF0, Centre_MeanF0, TimeF0AtPoint1, TimeF0AtPoint2, TimeF0AtPoint3, TimeF0AtPoint4, TimeF0AtPoint5, TimeF0AtPoint6, TimeF0AtPoint7, TimeF0AtPoint8, TimeF0AtPoint9, TimeF0AtPoint10, F0AtPoint1, F0AtPoint2, F0AtPoint3, F0AtPoint4, F0AtPoint5, F0AtPoint6, F0AtPoint7, F0AtPoint8, F0AtPoint9, F0AtPoint10]
# Index: []
#
# [0 rows x 50 columns]

# %%
full_sample_data.loc[927, 'Word'] = 'вопрос'
full_sample_data
# Out:
#                          Filename     Word  WordInterval Syllable  \
# 0                  Speaker_1_male   вечерa             2  'syll$'
# 1                  Speaker_1_male   вечерa             2  'syll$'
# 2                  Speaker_1_male   вечерa             2  'syll$'
# 3                  Speaker_1_male  олжаның             4  'syll$'
# 4                  Speaker_1_male  олжаның             4  'syll$'
# ...                           ...      ...           ...      ...
# 1971  Speaker_4_female_additional     окно           156  'syll$'
# 1972  Speaker_4_female_additional     гора           158  'syll$'
# 1973  Speaker_4_female_additional     гора           158  'syll$'
# 1974  Speaker_4_female_additional    сырға           160  'syll$'
# 1975  Speaker_4_female_additional    сырға           160  'syll$'
#
#                  SylInterval  SegIntervalNr                 Vowel       Begin  \
# 0     'parallelsyllinterval'              2             s1_cv_vʲɛ    1.889375
# 1     'parallelsyllinterval'              3  s2_cv_ʧʲɪ_unstressed    2.044858
# 2     'parallelsyllinterval'              4     s3_cv_ra_stressed    2.238501
# 3     'parallelsyllinterval'              6              s1_vc_ol    8.478645
# 4     'parallelsyllinterval'              7              s2_cv_ʒɑ    8.669182
# ...                      ...            ...                   ...         ...
# 1971  'parallelsyllinterval'            234   s2_ccv_kno_stressed  398.959062
# 1972  'parallelsyllinterval'            236        s1_cv_ɡʌ_pause  403.482342
# 1973  'parallelsyllinterval'            237     s2_cv_ra_stressed  403.784519
# 1974  'parallelsyllinterval'            239            s1_cvc_sər  408.327752
# 1975  'parallelsyllinterval'            240              s2_cv_ʁɑ  408.683643
#
#              End  Duration_in_ms  ...          F0AtPoint1          F0AtPoint2  \
# 0       2.044858      155.482845  ...  109.63265204141156  104.35065626539527
# 1       2.238501      193.642926  ...   108.1947021660767       --undefined--
# 2       2.499526      261.024641  ...  115.52645918680702  117.86416387695218
# 3       8.669182      190.536827  ...       --undefined--   123.7284450331763
# 4       8.915570      246.388278  ...  118.48326706520108  117.09417019379566
# ...          ...             ...  ...                 ...                 ...
# 1971  399.439655      480.592105  ...       --undefined--       --undefined--
# 1972  403.784519      302.177810  ...       --undefined--       --undefined--
# 1973  404.086697      302.177810  ...   280.0630737493057  278.85880546451733
# 1974  408.683643      355.890808  ...       --undefined--       --undefined--
# 1975  409.006706      323.062893  ...  238.92555967541682       --undefined--
#
#               F0AtPoint3          F0AtPoint4          F0AtPoint5  \
# 0     102.49127821549959  105.52702923754437  110.79783808095402
# 1          --undefined--       --undefined--       --undefined--
# 2     121.29690852810644  123.80898203049698   129.1979305385731
# 3     120.85441035690577  118.32445192588568  114.26760413960666
# 4     116.48717933813998   114.5024660615793   112.7206940243868
# ...                  ...                 ...                 ...
# 1971  246.48895075384854  232.74159198647908    230.467029163604
# 1972   175.8019646440638  217.02488005426304  208.93863487451924
# 1973  244.79838287400074  116.51275780077238  112.65014979021846
# 1974       --undefined--       --undefined--       --undefined--
# 1975       --undefined--   214.3459544731927  205.44445076468767
#
#               F0AtPoint6          F0AtPoint7          F0AtPoint8  \
# 0     116.12595990115243  117.94314337335328  116.39063899071706
# 1          --undefined--       --undefined--  124.37495874393628
# 2     136.61081017697276  146.63234866977515  154.93604548571605
# 3     111.71603508552155   113.7282582549003  117.92197121471601
# 4     116.28266974225471  118.16324849591815   115.9261553215855
# ...                  ...                 ...                 ...
# 1971   224.1702694030495  218.02993473046484  227.54182244463976
# 1972  223.12953273541066   241.8365263342389   264.4203175566175
# 1973  111.74023158396626  115.22541705709473  118.15196206515186
# 1974   284.0288893155089   293.0452036921328       --undefined--
# 1975  201.59031836631144   199.9015760593747   207.0959598575578
#
#               F0AtPoint9         F0AtPoint10
# 0     112.27079598361979   108.1947021660767
# 1     117.86532184168861  115.52645918680702
# 2      157.7039796119457   141.9820290517729
# 3     118.34365327483549  118.48326706520108
# 4     114.39753759926442  112.67862903968746
# ...                  ...                 ...
# 1971       --undefined--       --undefined--
# 1972   282.5889539864136   280.0630737493057
# 1973       --undefined--       --undefined--
# 1974   274.0988493118092  238.92555967541682
# 1975  212.43171558242364       --undefined--
#
# [1976 rows x 50 columns]

# %%
for i in full_sample_data.columns:
    print(i)
# print(sample_data.columns)
# Out:
# Filename
# Word
# WordInterval
# Syllable
# SylInterval
# SegIntervalNr
# Vowel
# Begin
# End
# Duration_in_ms
# Max_dB
# Min_dB
# TimeMax_dB
# TimeMin_dB
# Mean_dB
# Centre_mean_dB
# Centre_max_dB
# Centre_min_dB
# Word_beg
# Word_end
# Word_dur_ms
# Syl_beg
# Syl_end
# Syl_dur_ms
# MaxF0Hz
# TimeF0Max
# MinF0Hz
# TimeF0Min
# MeanF0
# Centre_MeanF0
# TimeF0AtPoint1
# TimeF0AtPoint2
# TimeF0AtPoint3
# TimeF0AtPoint4
# TimeF0AtPoint5
# TimeF0AtPoint6
# TimeF0AtPoint7
# TimeF0AtPoint8
# TimeF0AtPoint9
# TimeF0AtPoint10
# F0AtPoint1
# F0AtPoint2
# F0AtPoint3
# F0AtPoint4
# F0AtPoint5
# F0AtPoint6
# F0AtPoint7
# F0AtPoint8
# F0AtPoint9
# F0AtPoint10

# %%
# The columns we need: 'Filename', 'Word', 'Syllable','Vowel','Begin', 'End', 'Duration_in_ms','Mean_dB','Word_dur_ms','Syl_dur_ms', 
# 'MeanF0', ?calculated MeanF0 from 10 points

# %%
full_sample_data[full_sample_data['Vowel'].isna()]
# Out:
# Empty DataFrame
# Columns: [Filename, Word, WordInterval, Syllable, SylInterval, SegIntervalNr, Vowel, Begin, End, Duration_in_ms, Max_dB, Min_dB, TimeMax_dB, TimeMin_dB, Mean_dB, Centre_mean_dB, Centre_max_dB, Centre_min_dB, Word_beg, Word_end, Word_dur_ms, Syl_beg, Syl_end, Syl_dur_ms, MaxF0Hz, TimeF0Max, MinF0Hz, TimeF0Min, MeanF0, Centre_MeanF0, TimeF0AtPoint1, TimeF0AtPoint2, TimeF0AtPoint3, TimeF0AtPoint4, TimeF0AtPoint5, TimeF0AtPoint6, TimeF0AtPoint7, TimeF0AtPoint8, TimeF0AtPoint9, TimeF0AtPoint10, F0AtPoint1, F0AtPoint2, F0AtPoint3, F0AtPoint4, F0AtPoint5, F0AtPoint6, F0AtPoint7, F0AtPoint8, F0AtPoint9, F0AtPoint10]
# Index: []
#
# [0 rows x 50 columns]

# %%
# Replace '--undefined--' with NaN

#full_sample_data.replace('--undefined--', np.nan, inplace=True)

# %%
#print(sample_data[['MeanF0']])

# %% [markdown]
# ### The columns we need:
# - 'Filename'
# - 'Word'
# - 'Vowel'-- 'Syllable'
# - 'Begin', 'End'
# - 'Duration_in_ms' (vowel),
# - MaxdB, MindB
# - 'Mean_dB' (vowel),
# - centre_meandB
# - 'Word_dur_ms',
# - 'MeanF0' (syllable)
# - word begin, end
# - max fo
# - min f0
# - centre mean f0
# - fo point1-10
#     - mean of F0AtPoint1-Point10 is similar to MeanF0.
#     - is there any difference in this calculation?
#         - (11) **f0 at 10 equidistant points (can be used to create avarage time-normalized f0 contours)**
#         - (12) **time for these 10 equidistant points**

# %%
new_sd = full_sample_data[['Filename', 'Word', 'Word_beg','Word_end','Word_dur_ms','Vowel','Begin', 'End', 'Duration_in_ms','Max_dB','Min_dB', 'Mean_dB','Centre_mean_dB','MaxF0Hz','MinF0Hz','MeanF0','Centre_MeanF0']]

# %%
#new_sd.rename(columns={"Vowel": "Syllable"}, inplace=True)
#new_sd

new_sd = new_sd.copy()         
new_sd.rename(columns={"Vowel": "Annotation"}, inplace=True)
new_sd
# Out:
#                          Filename     Word    Word_beg    Word_end  \
# 0                  Speaker_1_male   вечерa    1.889375    2.499526
# 1                  Speaker_1_male   вечерa    1.889375    2.499526
# 2                  Speaker_1_male   вечерa    1.889375    2.499526
# 3                  Speaker_1_male  олжаның    8.478645    9.155741
# 4                  Speaker_1_male  олжаның    8.478645    9.155741
# ...                           ...      ...         ...         ...
# 1971  Speaker_4_female_additional     окно  398.826399  399.439655
# 1972  Speaker_4_female_additional     гора  403.482342  404.086697
# 1973  Speaker_4_female_additional     гора  403.482342  404.086697
# 1974  Speaker_4_female_additional    сырға  408.327752  409.006706
# 1975  Speaker_4_female_additional    сырға  408.327752  409.006706
#
#       Word_dur_ms            Annotation       Begin         End  \
# 0      610.150412             s1_cv_vʲɛ    1.889375    2.044858
# 1      610.150412  s2_cv_ʧʲɪ_unstressed    2.044858    2.238501
# 2      610.150412     s3_cv_ra_stressed    2.238501    2.499526
# 3      677.095577              s1_vc_ol    8.478645    8.669182
# 4      677.095577              s2_cv_ʒɑ    8.669182    8.915570
# ...           ...                   ...         ...         ...
# 1971   613.255551   s2_ccv_kno_stressed  398.959062  399.439655
# 1972   604.355619        s1_cv_ɡʌ_pause  403.482342  403.784519
# 1973   604.355619     s2_cv_ra_stressed  403.784519  404.086697
# 1974   678.953701            s1_cvc_sər  408.327752  408.683643
# 1975   678.953701              s2_cv_ʁɑ  408.683643  409.006706
#
#       Duration_in_ms     Max_dB     Min_dB    Mean_dB  Centre_mean_dB  \
# 0         155.482845  74.985990  63.362449  69.668919       69.955847
# 1         193.642926  78.978600  54.501599  69.067156       69.564769
# 2         261.024641  82.423066  62.212040  77.371060       81.115531
# 3         190.536827  79.912234  68.533809  77.636074       79.089145
# 4         246.388278  79.246411  72.590683  75.541177       74.920249
# ...              ...        ...        ...        ...             ...
# 1971      480.592105  69.127785  52.744015  64.442786       68.399444
# 1972      302.177810  75.707378  43.795685  69.512423       73.469518
# 1973      302.177810  74.260741  40.934942  67.350124       71.654074
# 1974      355.890808  77.374015  46.955878  69.869074       72.911484
# 1975      323.062893  74.321179  49.141829  68.174039       72.529912
#
#                  MaxF0Hz             MinF0Hz              MeanF0  \
# 0     117.94501777565652  102.48061042356133  110.45141920183515
# 1      134.5442548372237  105.78469042787755   119.9122666683785
# 2     158.85675082207482  114.03170346059693  135.30754057252486
# 3      129.2106468283745  111.47316521453874  117.96414989958585
# 4     118.48326706520108  112.45081127359856  115.66350048323727
# ...                  ...                 ...                 ...
# 1971  257.13410883608185   217.8142795800798   230.5511318516636
# 1972   285.4730316882915   155.3990954053691  232.93896847936605
# 1973  282.51776373132617  111.71723674820116  164.18209122959635
# 1974   297.5424642400837   238.9255596754168  279.24196314622105
# 1975  247.46734045434076   199.7715110822239  210.25724784942105
#
#            Centre_MeanF0
# 0     112.27203953943248
# 1      132.1938115430081
# 2     134.50084575302895
# 3      115.0118364127969
# 4     115.45099148902773
# ...                  ...
# 1971   227.5493482413709
# 1972  219.51178124256617
# 1973  119.95880583324052
# 1974   287.8251457071888
# 1975  206.51580155369655
#
# [1976 rows x 17 columns]

# %%
new_sd[new_sd['Annotation'].isna()]
# Out:
# Empty DataFrame
# Columns: [Filename, Word, Word_beg, Word_end, Word_dur_ms, Annotation, Begin, End, Duration_in_ms, Max_dB, Min_dB, Mean_dB, Centre_mean_dB, MaxF0Hz, MinF0Hz, MeanF0, Centre_MeanF0]
# Index: []

# %%
# Extract SyllStr, IPA, and Stress using a regex pattern
#new_sd[["SyllStr", "IPA", "Stress"]] = new_sd["Syllable"].str.extract(r"^s\d+_([^_]+)_((?:[^_]+))(?:_(stressed))?$")

# Fill NaN values in "Stress" with an empty string (optional)
#new_sd["Stress"] = new_sd["Stress"].fillna("")

# Update "Syllable" column to keep only the syllable position (s2, s3, etc.)
#new_sd["Syllable"] = new_sd["Syllable"].str.extract(r"^(s\d+)")


# Display the updated DataFrame
#new_sd[:15]

# %%
#new_sd[new_sd['SyllStr'].isna()]

# %%
#new_sd = new_sd[['Filename', 'Word', 'Word_beg','Word_end','Word_dur_ms','Syllable',"SyllStr",'IPA','Stress','Begin', 'End', 'Duration_in_ms','Max_dB','Min_dB', 'Mean_dB','Centre_mean_dB','MaxF0Hz','MinF0Hz','MeanF0','Centre_MeanF0']]
#new_sd[:10]

# %%
# Inner join on the 'Word' column metadata on CS and new_sd
# another option 'outer' join
meta_df = pd.merge(new_sd, stimulus_kaz_rus, on='Word', how='left')

# Display the result
meta_df
# Out:
#                          Filename     Word    Word_beg    Word_end  \
# 0                  Speaker_1_male   вечерa    1.889375    2.499526
# 1                  Speaker_1_male   вечерa    1.889375    2.499526
# 2                  Speaker_1_male   вечерa    1.889375    2.499526
# 3                  Speaker_1_male  олжаның    8.478645    9.155741
# 4                  Speaker_1_male  олжаның    8.478645    9.155741
# ...                           ...      ...         ...         ...
# 1971  Speaker_4_female_additional     окно  398.826399  399.439655
# 1972  Speaker_4_female_additional     гора  403.482342  404.086697
# 1973  Speaker_4_female_additional     гора  403.482342  404.086697
# 1974  Speaker_4_female_additional    сырға  408.327752  409.006706
# 1975  Speaker_4_female_additional    сырға  408.327752  409.006706
#
#       Word_dur_ms            Annotation       Begin         End  \
# 0      610.150412             s1_cv_vʲɛ    1.889375    2.044858
# 1      610.150412  s2_cv_ʧʲɪ_unstressed    2.044858    2.238501
# 2      610.150412     s3_cv_ra_stressed    2.238501    2.499526
# 3      677.095577              s1_vc_ol    8.478645    8.669182
# 4      677.095577              s2_cv_ʒɑ    8.669182    8.915570
# ...           ...                   ...         ...         ...
# 1971   613.255551   s2_ccv_kno_stressed  398.959062  399.439655
# 1972   604.355619        s1_cv_ɡʌ_pause  403.482342  403.784519
# 1973   604.355619     s2_cv_ra_stressed  403.784519  404.086697
# 1974   678.953701            s1_cvc_sər  408.327752  408.683643
# 1975   678.953701              s2_cv_ʁɑ  408.683643  409.006706
#
#       Duration_in_ms     Max_dB  ...             MaxF0Hz             MinF0Hz  \
# 0         155.482845  74.985990  ...  117.94501777565652  102.48061042356133
# 1         193.642926  78.978600  ...   134.5442548372237  105.78469042787755
# 2         261.024641  82.423066  ...  158.85675082207482  114.03170346059693
# 3         190.536827  79.912234  ...   129.2106468283745  111.47316521453874
# 4         246.388278  79.246411  ...  118.48326706520108  112.45081127359856
# ...              ...        ...  ...                 ...                 ...
# 1971      480.592105  69.127785  ...  257.13410883608185   217.8142795800798
# 1972      302.177810  75.707378  ...   285.4730316882915   155.3990954053691
# 1973      302.177810  74.260741  ...  282.51776373132617  111.71723674820116
# 1974      355.890808  77.374015  ...   297.5424642400837   238.9255596754168
# 1975      323.062893  74.321179  ...  247.46734045434076   199.7715110822239
#
#                   MeanF0       Centre_MeanF0 Language SuffixCase     WordForm  \
# 0     110.45141920183515  112.27203953943248      Rus        GEN    inflected
# 1      119.9122666683785   132.1938115430081      Rus        GEN    inflected
# 2     135.30754057252486  134.50084575302895      Rus        GEN    inflected
# 3     117.96414989958585   115.0118364127969      Kaz        GEN    inflected
# 4     115.66350048323727  115.45099148902773      Kaz        GEN    inflected
# ...                  ...                 ...      ...        ...          ...
# 1971   230.5511318516636   227.5493482413709       CS        NaN  uninflected
# 1972  232.93896847936605  219.51178124256617       CS        NaN  uninflected
# 1973  164.18209122959635  119.95880583324052       CS        NaN  uninflected
# 1974  279.24196314622105   287.8251457071888      Kaz        NaN  uninflected
# 1975  210.25724784942105  206.51580155369655      Kaz        NaN  uninflected
#
#      LatinScript        Gloss WordClass
# 0        vechera  evening.ACC      Noun
# 1        vechera  evening.ACC      Noun
# 2        vechera  evening.ACC      Noun
# 3        oljanyń   trophy.GEN      Noun
# 4        oljanyń   trophy.GEN      Noun
# ...          ...          ...       ...
# 1971        okno       window      Noun
# 1972        gora     mountain      Noun
# 1973        gora     mountain      Noun
# 1974       syrǵa      earring      Noun
# 1975       syrǵa      earring      Noun
#
# [1976 rows x 23 columns]

# %%
# Mispronounced tokens - 7

meta_df.loc[234, 'Language'] = 'Rus'
meta_df.loc[234, 'SuffixCase'] = 'DAT'
meta_df.loc[234, 'WordForm'] = 'inflected'
meta_df.loc[234, 'LatinScript'] = 'vole'
meta_df.loc[234, 'Gloss'] = 'will.DAT'
meta_df.loc[234, 'WordClass'] = 'Noun'

meta_df.loc[235, 'Language'] = 'Rus'
meta_df.loc[235, 'SuffixCase'] = 'DAT'
meta_df.loc[235, 'WordForm'] = 'inflected'
meta_df.loc[235, 'LatinScript'] = 'vole'
meta_df.loc[235, 'Gloss'] = 'will.DAT'
meta_df.loc[235, 'WordClass'] = 'Noun'  

meta_df[meta_df['Language'].isna()]
# Out:
#               Filename         Word    Word_beg    Word_end  Word_dur_ms  \
# 212     Speaker_1_male    небa_misp  348.449254  349.246923   797.668972
# 213     Speaker_1_male    небa_misp  348.449254  349.246923   797.668972
# 1331  Speaker_4_female    вины_misp   22.973543   23.479154   505.611348
# 1332  Speaker_4_female    вины_misp   22.973543   23.479154   505.611348
# 1335  Speaker_4_female  звезды_misp   29.478327   30.142977   664.650269
# 1336  Speaker_4_female  звезды_misp   29.478327   30.142977   664.650269
# 1345  Speaker_4_female    горы_misp   42.649277   43.162072   512.795014
# 1346  Speaker_4_female    горы_misp   42.649277   43.162072   512.795014
# 1436  Speaker_4_female    души_misp  187.679216  188.293282   614.066310
# 1437  Speaker_4_female    души_misp  187.679216  188.293282   614.066310
# 1629  Speaker_4_female  вечерa_misp  544.601199  545.285130   683.930333
# 1630  Speaker_4_female  вечерa_misp  544.601199  545.285130   683.930333
# 1631  Speaker_4_female  вечерa_misp  544.601199  545.285130   683.930333
# 1651  Speaker_4_female    селa_misp  592.343181  592.907765   564.583226
# 1652  Speaker_4_female    селa_misp  592.343181  592.907765   564.583226
#
#                   Annotation       Begin         End  Duration_in_ms  \
# 212                 s1_cv_ne  348.449254  348.964741      515.487249
# 213        s2_cv_bʌ_stressed  348.964741  349.246923      282.181723
# 1331      s1_cv_vʲi_stressed   22.973543   23.171554      198.010783
# 1332                s2_cv_nɨ   23.171554   23.479154      307.600565
# 1335  s1_ccvc_zvʲoz_stressed   29.478327   29.835904      357.576676
# 1336                s3_cv_dɨ   29.835904   30.142977      307.073593
# 1345       s1_cv_ɡo_stressed   42.649277   42.879933      230.656503
# 1346                s2_cv_rɨ   42.879933   43.162072      282.138511
# 1436       s1_cv_du_stressed  187.679216  187.908059      228.843459
# 1437                s2_cv_ʃi  187.908059  188.293282      385.222851
# 1629               s1_cv_vʲe  544.601199  544.744028      142.828825
# 1630               s2_cv_ʧʲɪ  544.744028  544.963765      219.736653
# 1631       s3_cv_ra_stressed  544.963765  545.285130      321.364855
# 1651      s1_cv_sʲe_stressed  592.343181  592.619841      276.659715
# 1652                s2_cv_la  592.619841  592.907765      287.923511
#
#          Max_dB  ...  WordForm  LatinScript  Gloss WordClass StressedSyll  \
# 212   79.698002  ...       NaN          NaN    NaN       NaN          NaN
# 213   81.836902  ...       NaN          NaN    NaN       NaN          NaN
# 1331  76.427367  ...       NaN          NaN    NaN       NaN          NaN
# 1332  73.505544  ...       NaN          NaN    NaN       NaN          NaN
# 1335  77.087215  ...       NaN          NaN    NaN       NaN          NaN
# 1336  76.447961  ...       NaN          NaN    NaN       NaN          NaN
# 1345  78.390866  ...       NaN          NaN    NaN       NaN          NaN
# 1346  75.068718  ...       NaN          NaN    NaN       NaN          NaN
# 1436  71.924373  ...       NaN          NaN    NaN       NaN          NaN
# 1437  76.944601  ...       NaN          NaN    NaN       NaN          NaN
# 1629  76.375493  ...       NaN          NaN    NaN       NaN          NaN
# 1630  76.721243  ...       NaN          NaN    NaN       NaN          NaN
# 1631  74.651210  ...       NaN          NaN    NaN       NaN          NaN
# 1651  72.175864  ...       NaN          NaN    NaN       NaN          NaN
# 1652  70.703287  ...       NaN          NaN    NaN       NaN          NaN
#
#      NounGender Declension StressShift ShiftDirect AttestedInCS
# 212         NaN        NaN         NaN         NaN          NaN
# 213         NaN        NaN         NaN         NaN          NaN
# 1331        NaN        NaN         NaN         NaN          NaN
# 1332        NaN        NaN         NaN         NaN          NaN
# 1335        NaN        NaN         NaN         NaN          NaN
# 1336        NaN        NaN         NaN         NaN          NaN
# 1345        NaN        NaN         NaN         NaN          NaN
# 1346        NaN        NaN         NaN         NaN          NaN
# 1436        NaN        NaN         NaN         NaN          NaN
# 1437        NaN        NaN         NaN         NaN          NaN
# 1629        NaN        NaN         NaN         NaN          NaN
# 1630        NaN        NaN         NaN         NaN          NaN
# 1631        NaN        NaN         NaN         NaN          NaN
# 1651        NaN        NaN         NaN         NaN          NaN
# 1652        NaN        NaN         NaN         NaN          NaN
#
# [15 rows x 29 columns]

# %%
meta_df.loc[235, 'WordClass']
# Out:
# 'Noun'

# %%
meta_df = pd.merge(meta_df, stimulus_cs, on='Word', how='left')

meta_df[:20]
# Out:
#           Filename      Word   Word_beg   Word_end  Word_dur_ms  \
# 0   Speaker_1_male    вечерa   1.889375   2.499526   610.150412
# 1   Speaker_1_male    вечерa   1.889375   2.499526   610.150412
# 2   Speaker_1_male    вечерa   1.889375   2.499526   610.150412
# 3   Speaker_1_male   олжаның   8.478645   9.155741   677.095577
# 4   Speaker_1_male   олжаның   8.478645   9.155741   677.095577
# 5   Speaker_1_male   олжаның   8.478645   9.155741   677.095577
# 6   Speaker_1_male   шекелер  13.508227  14.150535   642.307868
# 7   Speaker_1_male   шекелер  13.508227  14.150535   642.307868
# 8   Speaker_1_male   шекелер  13.508227  14.150535   642.307868
# 9   Speaker_1_male   сөрелер  18.792268  19.419988   627.719622
# 10  Speaker_1_male   сөрелер  18.792268  19.419988   627.719622
# 11  Speaker_1_male   сөрелер  18.792268  19.419988   627.719622
# 12  Speaker_1_male   рекалар  23.738292  24.305039   566.747174
# 13  Speaker_1_male   рекалар  23.738292  24.305039   566.747174
# 14  Speaker_1_male   рекалар  23.738292  24.305039   566.747174
# 15  Speaker_1_male   төбенің  28.520158  29.032467   512.309266
# 16  Speaker_1_male   төбенің  28.520158  29.032467   512.309266
# 17  Speaker_1_male   төбенің  28.520158  29.032467   512.309266
# 18  Speaker_1_male  помощьты  33.162514  33.793248   630.734124
# 19  Speaker_1_male  помощьты  33.162514  33.793248   630.734124
#
#                  Annotation      Begin        End  Duration_in_ms     Max_dB  \
# 0                 s1_cv_vʲɛ   1.889375   2.044858      155.482845  74.985990
# 1      s2_cv_ʧʲɪ_unstressed   2.044858   2.238501      193.642926  78.978600
# 2         s3_cv_ra_stressed   2.238501   2.499526      261.024641  82.423066
# 3                  s1_vc_ol   8.478645   8.669182      190.536827  79.912234
# 4                  s2_cv_ʒɑ   8.669182   8.915570      246.388278  79.246411
# 5                s3_cvc_nəŋ   8.915570   9.155325      239.754521  76.262425
# 6                 s1_cv_ʃie  13.508227  13.757677      249.449606  76.437268
# 7                 s2_cv_kie  13.757677  13.923753      166.076394  82.803796
# 8               s3_cvc_lier  13.923753  14.150535      226.781868  79.860326
# 9                  s1_cv_sɵ  18.792268  19.070072      277.803623  83.057102
# 10                s2_cv_rie  19.070072  19.180671      110.598637  84.276363
# 11              s3_cvc_lier  19.180671  19.419988      239.317362  80.634955
# 12                s1_cv_rʲe  23.738292  23.921023      182.731270  81.398802
# 13        s2_cv_ka_stressed  23.921023  24.084790      163.766249  83.182984
# 14               s3_cvc_lɑr  24.084790  24.305039      220.249656  82.204311
# 15           s1_cv_tɵ_pause  28.520158  28.663942      143.783974  78.489845
# 16                s2_cv_bie  28.663942  28.816829      152.886352  81.803076
# 17               s3_cvc_nɪŋ  28.816829  29.032467      215.638941  76.282917
# 18  s1_cv_po_stressed_pause  33.162514  33.300549      138.034853  82.757223
# 19             s2_cvc_məʃːʲ  33.300549  33.572241      271.692275  75.753235
#
#     ...   WordForm  LatinScript        Gloss WordClass StressedSyll  \
# 0   ...  inflected      vechera  evening.ACC      Noun          1.0
# 1   ...  inflected      vechera  evening.ACC      Noun          1.0
# 2   ...  inflected      vechera  evening.ACC      Noun          1.0
# 3   ...  inflected      oljanyń   trophy.GEN      Noun          NaN
# 4   ...  inflected      oljanyń   trophy.GEN      Noun          NaN
# 5   ...  inflected      oljanyń   trophy.GEN      Noun          NaN
# 6   ...  inflected     shekeler  forehead.Pl      Noun          NaN
# 7   ...  inflected     shekeler  forehead.Pl      Noun          NaN
# 8   ...  inflected     shekeler  forehead.Pl      Noun          NaN
# 9   ...  inflected      sóreler     shelf.Pl      Noun          NaN
# 10  ...  inflected      sóreler     shelf.Pl      Noun          NaN
# 11  ...  inflected      sóreler     shelf.Pl      Noun          NaN
# 12  ...  inflected      rekalar     river.Pl      Noun          2.0
# 13  ...  inflected      rekalar     river.Pl      Noun          2.0
# 14  ...  inflected      rekalar     river.Pl      Noun          2.0
# 15  ...  inflected      tóbeniń     hill.GEN      Noun          NaN
# 16  ...  inflected      tóbeniń     hill.GEN      Noun          NaN
# 17  ...  inflected      tóbeniń     hill.GEN      Noun          NaN
# 18  ...  inflected     pomoshty     help.ACC      Noun          1.0
# 19  ...  inflected     pomoshty     help.ACC      Noun          1.0
#
#    NounGender Declension StressShift ShiftDirect AttestedInCS
# 0           m        2.0         yes     forward          yes
# 1           m        2.0         yes     forward          yes
# 2           m        2.0         yes     forward          yes
# 3         NaN        NaN         NaN         NaN          NaN
# 4         NaN        NaN         NaN         NaN          NaN
# 5         NaN        NaN         NaN         NaN          NaN
# 6         NaN        NaN         NaN         NaN          NaN
# 7         NaN        NaN         NaN         NaN          NaN
# 8         NaN        NaN         NaN         NaN          NaN
# 9         NaN        NaN         NaN         NaN          NaN
# 10        NaN        NaN         NaN         NaN          NaN
# 11        NaN        NaN         NaN         NaN          NaN
# 12          f        2.0         yes    backward          yes
# 13          f        2.0         yes    backward          yes
# 14          f        2.0         yes    backward          yes
# 15        NaN        NaN         NaN         NaN          NaN
# 16        NaN        NaN         NaN         NaN          NaN
# 17        NaN        NaN         NaN         NaN          NaN
# 18          f        3.0          no          na          yes
# 19          f        3.0          no          na          yes
#
# [20 rows x 29 columns]

# %%
meta_df.to_csv('final_df.csv', index=False)

# %%
pwd
# Out:
# '/Users/aidyn/Documents/Fall_2024_IndStudy/CompletedAnnotations'

# %% [markdown]
# ### Formants dataset

# %%
import pandas as pd
import glob
import os
from charset_normalizer import from_path

# Define your folder path
folder_path = "/Users/aidyn/Documents/Fall_2024_IndStudy/CompletedAnnotations/formants_new"

# Get list of all CSV files in the folder
csv_files = glob.glob(os.path.join(folder_path, "*.csv"))

# Function to detect encoding using charset-normalizer and read CSV
def read_csv_with_encoding(file_path):
    result = from_path(file_path).best()
    encoding = result.encoding if result else 'utf-8-sig'  # fallback to utf-8
    print(f"Reading {os.path.basename(file_path)} as {encoding}")
    return pd.read_csv(file_path, encoding=encoding)

# Read and combine all CSV files safely
dfs = []
for file in csv_files:
    try:
        df = read_csv_with_encoding(file)
        dfs.append(df)
    except Exception as e:
        print(f"❌ Failed to read {file}: {e}")

# Combine into one DataFrame
df_formants_all = pd.concat(dfs, ignore_index=True)

# Show first few rows
df_formants_all.head()
# Out:
# Reading formants6.csv as utf-8-sig
# ❌ Failed to read /Users/aidyn/Documents/Fall_2024_IndStudy/CompletedAnnotations/formants_new/formants6.csv: 'utf-8' codec can't decode byte 0xb2 in position 219: invalid start byte
# Reading formants7.csv as utf-8-sig
# ❌ Failed to read /Users/aidyn/Documents/Fall_2024_IndStudy/CompletedAnnotations/formants_new/formants7.csv: 'utf-8' codec can't decode byte 0xb2 in position 103: invalid start byte
# Reading formants5.csv as utf-8-sig
# ❌ Failed to read /Users/aidyn/Documents/Fall_2024_IndStudy/CompletedAnnotations/formants_new/formants5.csv: 'utf-8' codec can't decode byte 0x92 in position 97: invalid start byte
# Reading formants4.csv as utf-8-sig
# ❌ Failed to read /Users/aidyn/Documents/Fall_2024_IndStudy/CompletedAnnotations/formants_new/formants4.csv: 'utf-8' codec can't decode byte 0xb2 in position 90: invalid start byte
# Reading formants1.csv as utf_8
# Reading formants3.csv as utf-8-sig
# ❌ Failed to read /Users/aidyn/Documents/Fall_2024_IndStudy/CompletedAnnotations/formants_new/formants3.csv: 'utf-8' codec can't decode byte 0xb2 in position 94: invalid start byte
# Reading formants2.csv as utf-8-sig
# ❌ Failed to read /Users/aidyn/Documents/Fall_2024_IndStudy/CompletedAnnotations/formants_new/formants2.csv: 'utf-8' codec can't decode byte 0x93 in position 90: invalid start byte
# Reading formants8.csv as utf-8-sig
# ❌ Failed to read /Users/aidyn/Documents/Fall_2024_IndStudy/CompletedAnnotations/formants_new/formants8.csv: 'utf-8' codec can't decode byte 0xb1 in position 85: invalid start byte
#              file      time         word        phoneme  duration  \
# 0  Speaker_1_male  0.944688          NaN            NaN  1.889375
# 1  Speaker_1_male  1.923856  25G5@a            v≤  0.068962
# 2  Speaker_1_male  2.001483  25G5@a  [_unstressed  0.086293
# 3  Speaker_1_male  2.119540  25G5@a           ß≤  0.149821
# 4  Speaker_1_male  2.216664  25G5@a  j_unstressed  0.044427
#
#             F1           F2           F3
# 0   700.622436  1433.047342  2194.326500
# 1   183.441796  1435.802227  2413.905369
# 2   332.122411  1829.017775  2551.170752
# 3  2097.484220  2741.175778  3187.176626
# 4   476.466234  1491.016454  2458.569107
